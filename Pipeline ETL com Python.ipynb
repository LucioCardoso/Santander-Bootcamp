# %%
import pandas as pd
import json
# from openai import OpenAI
import google.generativeai as genai

# %%
# Criar DataFrame a partir da leitura do arquivo CSV
df = pd.read_csv('SDW2023.csv')

# Carregar em user_ids somente os dados correspondentes da coluna UserID
user_ids = df['UserID'].tolist()
print(user_ids)
# Out:
# [4, 5, 6]

# %%
# Carregar os usuários do arquivo JSON
with open ('users.json', 'r', encoding = 'utf-8') as file:
    all_users = json.load(file)

# Filtrar apenas os usuários cujo ID está na lista user_ids
users = [user for user in all_users if user['id'] in user_ids]

# Imprimir o JSON formatado
print(json.dumps(users, indent=3))
# Out:
# [
#    {
#       "id": 4,
#       "name": "Pytherson",
#       "account": {
#          "id": 7,
#          "number": "00001-1",
#          "agency": "0001",
#          "balance": 0,
#          "limit": 500
#       },
#       "card": {
#          "id": 4,
#          "number": "**** **** **** 1111",
#          "limit": 1000
#       },
#       "features": [],
#       "news": [
#          {
#             "description": "Pytherson, invista! Seu dinheiro trabalhando hoje garante o futuro que voc\u00ea sonha amanh\u00e3."
#          },
#          {
#             "description": "Pytherson, seu futuro n\u00e3o espera. Invista e fa\u00e7a seu dinheiro trabalhar para voc\u00ea!"
#          }
#       ]
#    },
#    {
#       "id": 5,
#       "name": "Pip",
#       "account": {
#          "id": 8,
#          "number": "00002-2",
#          "agency": "0001",
#          "balance": 50,
#          "limit": 500
#       },
#       "card": {
#          "id": 5,
#          "number": "**** **** **** 2222",
#          "limit": 1200
#       },
#       "features": [],
#       "news": [
#          {
#             "description": "Pip, invista! Fa\u00e7a seu dinheiro trabalhar por voc\u00ea. Conquiste seu futuro dos sonhos. Comece j\u00e1!"
#          },
#          {
#             "description": "Invista, Pip! Seu dinheiro merece um futuro brilhante. Fa\u00e7a-o render e construa sua seguran\u00e7a."
#          }
#       ]
#    },
#    {
#       "id": 6,
#       "name": "Pep",
#       "account": {
#          "id": 9,
#          "number": "00003-3",
#          "agency": "0001",
#          "balance": 100,
#          "limit": 500
#       },
#       "card": {
#          "id": 6,
#          "number": "**** **** **** 3333",
#          "limit": 1500
#       },
#       "features": [],
#       "news": [
#          {
#             "description": "Pep, invista! Seu futuro agradece. Fa\u00e7a seu dinheiro crescer e realize seus sonhos."
#          },
#          {
#             "description": "Pep, invista no seu futuro! Fa\u00e7a seu dinheiro crescer e realize seus sonhos. Comece hoje!"
#          }
#       ]
#    }
# ]

# %%
# Código para usar chave ChatGPT
"""openai_api_key = 'sk-proj-2Ww2CSEA_Nq76Ul3qKIvgFPOtO2174OryV-ZcAfNjAFtXVQB-GIGT'

client = OpenAI(api_key=openai_api_key)
"""
# Out:
# "openai_api_key = 'sk-proj-2Ww2CSEA_Nq76Ul3qKIvgFPOtO2174OryV-ZcAfNjAFtXVQB-GIGT'\n\nclient = OpenAI(api_key=openai_api_key)\n"

# %%
# Código para usar ChatGPT
'''
def generate_ai_news(user):
    completion = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {
                "role": "system",
                "content": "Você é um especialista em Marketing Digital Bancário."
            },
            {
                "role": "user",
                "content": f"Crie uma mensagem para {user['name']} sobre a importância dos investimentos (máximo de 100 caracteres)"
            }
        ]
    )
    return completion.choices[0].message.content.strip('"')

for user in users:
    news = generate_ai_news(user)
    print(news)
    user['news'].append({
        "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",
        "description": news
    })
'''
# Out:
# '\ndef generate_ai_news(user):\n    completion = client.chat.completions.create(\n        model="gpt-3.5-turbo",\n        messages=[\n            {\n                "role": "system",\n                "content": "Você é um especialista em Marketing Digital Bancário."\n            },\n            {\n                "role": "user",\n                "content": f"Crie uma mensagem para {user[\'name\']} sobre a importância dos investimentos (máximo de 100 caracteres)"\n            }\n        ]\n    )\n    return completion.choices[0].message.content.strip(\'"\')\n\nfor user in users:\n    news = generate_ai_news(user)\n    print(news)\n    user[\'news\'].append({\n        "icon": "https://digitalinnovationone.github.io/santander-dev-week-2023-api/icons/credit.svg",\n        "description": news\n    })\n'

# %%
# Configurar a API do Google Gemini
gemini_api_key = 'xxxxxxx'
genai.configure(api_key=gemini_api_key)

# %%
# Criar o modelo
model = genai.GenerativeModel('gemini-2.5-flash')

def generate_ai_news(user):
    prompt = f"""Você é um especialista em Marketing Digital Bancário.
    
Crie uma mensagem para {user['name']} sobre a importância dos investimentos.
A mensagem deve ter no máximo 100 caracteres.
Não mostre mensagens sobre a quantidade de caracteres utilizados (exemplo 83 caracteres)."""
    
    response = model.generate_content(prompt)
    return response.text.strip('*')

for user in users:
    news = generate_ai_news(user)
    print(news)
    user['news'].append({
        "description": news
    })
# Out:
# Pytherson, seu futuro merece ser seguro. Invista hoje, colha amanhã!
# Pip, faça seu dinheiro trabalhar por você! Invista no seu futuro e construa a vida que você sonha.
# Pep, o futuro é seu! Invista hoje e faça seu dinheiro trabalhar por você. Conquiste sua liberdade financeira.

# %%
# Imprimir o JSON formatado
print(json.dumps(users, indent=3))
# Out:
# [
#    {
#       "id": 4,
#       "name": "Pytherson",
#       "account": {
#          "id": 7,
#          "number": "00001-1",
#          "agency": "0001",
#          "balance": 0,
#          "limit": 500
#       },
#       "card": {
#          "id": 4,
#          "number": "**** **** **** 1111",
#          "limit": 1000
#       },
#       "features": [],
#       "news": [
#          {
#             "description": "Pytherson, invista! Seu dinheiro trabalhando hoje garante o futuro que voc\u00ea sonha amanh\u00e3."
#          },
#          {
#             "description": "Pytherson, seu futuro n\u00e3o espera. Invista e fa\u00e7a seu dinheiro trabalhar para voc\u00ea!"
#          },
#          {
#             "description": "Pytherson, seu futuro merece ser seguro. Invista hoje, colha amanh\u00e3!"
#          }
#       ]
#    },
#    {
#       "id": 5,
#       "name": "Pip",
#       "account": {
#          "id": 8,
#          "number": "00002-2",
#          "agency": "0001",
#          "balance": 50,
#          "limit": 500
#       },
#       "card": {
#          "id": 5,
#          "number": "**** **** **** 2222",
#          "limit": 1200
#       },
#       "features": [],
#       "news": [
#          {
#             "description": "Pip, invista! Fa\u00e7a seu dinheiro trabalhar por voc\u00ea. Conquiste seu futuro dos sonhos. Comece j\u00e1!"
#          },
#          {
#             "description": "Invista, Pip! Seu dinheiro merece um futuro brilhante. Fa\u00e7a-o render e construa sua seguran\u00e7a."
#          },
#          {
#             "description": "Pip, fa\u00e7a seu dinheiro trabalhar por voc\u00ea! Invista no seu futuro e construa a vida que voc\u00ea sonha."
#          }
#       ]
#    },
#    {
#       "id": 6,
#       "name": "Pep",
#       "account": {
#          "id": 9,
#          "number": "00003-3",
#          "agency": "0001",
#          "balance": 100,
#          "limit": 500
#       },
#       "card": {
#          "id": 6,
#          "number": "**** **** **** 3333",
#          "limit": 1500
#       },
#       "features": [],
#       "news": [
#          {
#             "description": "Pep, invista! Seu futuro agradece. Fa\u00e7a seu dinheiro crescer e realize seus sonhos."
#          },
#          {
#             "description": "Pep, invista no seu futuro! Fa\u00e7a seu dinheiro crescer e realize seus sonhos. Comece hoje!"
#          },
#          {
#             "description": "Pep, o futuro \u00e9 seu! Invista hoje e fa\u00e7a seu dinheiro trabalhar por voc\u00ea. Conquiste sua liberdade financeira."
#          }
#       ]
#    }
# ]

# %%
# Atualizar a lista de "news" de cada usuário na API com a nova mensagem gerada pela IA
def update_user(user):
    """Simula a atualização salvando no arquivo JSON local"""
    try:
        # Ler o arquivo JSON atual
        with open('users.json', 'r', encoding='utf-8') as file:
            all_users = json.load(file)
        
        # Encontrar e atualizar o usuário específico
        for i, usuario in enumerate(all_users):
            if usuario['id'] == user['id']:
                all_users[i] = user
                break
        
        # Salvar de volta no arquivo
        with open('users.json', 'w', encoding='utf-8') as file:
            json.dump(all_users, file, indent=2, ensure_ascii=False)
        
        return True
    except Exception as e:
        print(f"Erro ao atualizar usuário {user['id']}: {e}")
        return False

# Atualizar cada usuário
for user in users:
    success = update_user(user)
    if success:
        print(f"✅ Usuário {user['name']} atualizado com sucesso!")
    else:
        print(f"❌ Falha ao atualizar usuário {user['name']}")
# Out:
# ✅ Usuário Pytherson atualizado com sucesso!
# ✅ Usuário Pip atualizado com sucesso!
# ✅ Usuário Pep atualizado com sucesso!
